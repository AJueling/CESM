# %%
import scipy.stats as stats
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from paths import file_ex_ocn_ctrl, path_results

# %%
ds = xr.open_dataset(file_ex_ocn_ctrl, decode_times=False)

# %%
ds.TEMP.shape[1:]
# Out:
# (42, 2400, 3600)

# %%
2400*3600*300e-6/60
# Out:
# 43.2

# %% [markdown]
# ### stats.linregress

# %%
stats.linregress(np.arange(0,100), B[:,0])
# Out:
# LinregressResult(slope=0.0016380619800468851, intercept=0.45035457992384864, rvalue=0.1640098335417755, pvalue=0.10298746441786923, stderr=0.0009952365423716136)

# %%
# %%timeit
A = np.random.random((100,100,10))
(nt, nx, ny) = np.shape(A)
N = nx*ny
B = A.reshape((nt,N))
C = np.empty((N, 5))
for i in range(N):
    C[i,:] = stats.linregress(np.arange(0,nt), B[:,i])
C = C.reshape((nx,ny,5))
# Out:
# 319 ms ± 3.58 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### np.polynomial.polynomial.polyfit

# %%
np.polynomial.polynomial.polyfit(np.arange(0,nt), B[:,i], 1)
# Out:
# array([ 0.5553644 , -0.00059179])

# %%
# %%timeit
A = np.random.random((100,100,10))
(nt, nx, ny) = np.shape(A)
N = nx*ny
B = A.reshape((nt,N))
C = np.empty((N, 2))
for i in range(N):
    C[i,:] = np.polynomial.polynomial.polyfit(np.arange(0,nt), B[:,i], 1)
C = C.reshape((nx,ny,2))
# Out:
# 175 ms ± 417 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### np.polyfit

# %%
np.polyfit(np.arange(0,nt), B[:,i], 1)
# Out:
# array([-0.00059179,  0.5553644 ])

# %%
# %%timeit
A = np.random.random((100,100,10))
(nt, nx, ny) = np.shape(A)
N = nx*ny
B = A.reshape((nt,N))
C = np.empty((N, 2))
for i in range(N):
    C[i,:] = np.polyfit(np.arange(0,nt), B[:,i], 1)
C = C.reshape((nx,ny,2))
# Out:
# 138 ms ± 687 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
A = np.random.random((100,100,100))
(nt, nx, ny) = np.shape(A)
N = nx*ny
B = A.reshape((nt,N))
C = np.empty((2, N))
# for i in range(N):
C[:,:] = np.polyfit(np.arange(0,nt), B[:,:], 1)
print(C.shape)
C = C.reshape((nx,ny,2))
# Out:
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# (2, 10000)
# ...

# %%
D = B.copy()

# %%
D[:,10:90] = np.nan

# %%
n = nx * ny
frain = rainStack.reshape((n, 8))
fnpp = nppStack.reshape((n, 8))
reg_results = np.empty((n,5))
for i in range(n):
    reg_results[i] = stats.linregress(frain[i], fnpp[i])
reg_results[i].reshape((nx,ny,8))    # back to 3D

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 384, year: 81)
# Coordinates:
#   * year     (year) int64 2000 2001 2002 2003 2004 ... 2076 2077 2078 2079 2080
#   * lat      (lat) float64 -90.0 -89.53 -89.06 -88.59 ... 88.59 89.06 89.53 90.0
# Data variables:
#     GMST     (year) float64 ...
#     T_zonal  (year, lat) float64 ...

# %%
# %%timeit
np.polynomial.polynomial.polyfit(ds.year, ds.GMST, 1)[1]
# Out:
# 766 µs ± 5.56 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
from xr_regression import xr_linear_trend

# %%
da[100,100]
# Out:
# <xarray.DataArray 'TEMP' ()>
# array(-1., dtype=float32)
# Coordinates:
#     time     float64 7.302e+04
#     z_t      float32 500.622
#     ULONG    float64 -1.0
#     ULAT     float64 -1.0
#     TLONG    float64 -1.0
#     TLAT     float64 -1.0
# Attributes:
#     long_name:     Potential Temperature
#     units:         degC
#     grid_loc:      3111
#     cell_methods:  time: mean

# %%
# %%timeit
stacked.groupby('allpoints').apply(xr_linear_trend)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-21-c0af08475983> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "stacked.groupby('allpoints').apply(xr_linear_trend)\n")
#
# ~/.conda/envs/CESM/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2319             magic_arg_s = self.var_expand(line, stack_depth)
#    2320             with self.builtin_trap:
# -> 2321                 result = fn(magic_arg_s, cell)
#    2322             return result
#    2323
#
# <decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ~/.conda/envs/CESM/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...
